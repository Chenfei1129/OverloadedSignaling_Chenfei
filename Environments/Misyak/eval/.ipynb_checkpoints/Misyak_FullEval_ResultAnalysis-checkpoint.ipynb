# %%
import sys
sys.path.append('/home/stacyste/Documents/Research/OverloadedSignaling/Environments/Misyak')
sys.path.append('/home/stacyste/Documents/Research/OverloadedSignaling/Environments/Misyak/eval')
import numpy as np
import pandas as pd

from evaluateMisyak_FullExperimentalConditions import EvaluateOverloadedSignaler

# %%
# %load_ext autoreload
# %autoreload 2

# %%
humanResults = pd.read_pickle('/home/stacyste/Documents/Research/OverloadedSignaling/Environments/Misyak/data/humanResultsStrategyPDFs.pkl')
#mod_meaning05 = pd.read_pickle('./evalResults-2020-8-24-AlphaRewardPunishmentSignal.pkl')
#modMeaning = pd.read_pickle('./evalResults-2020-8-25-MeaningPrior.pkl')
#modMTargeted = pd.read_pickle('./evalResults-2020-8-25-MeaningPrior0525-6Alpha1-10Only.pkl')
tuneGrid828 = pd.read_pickle('./evalResults-2020-8-28-valueFixed1-cost01-signalCost.pkl')

# %%
def getMatchingStrategies(modelPreds):
    indxNames = list(modelPreds.index.names)
    indxNames.remove('strategy')
    
    hStrat = modelPreds.groupby(indxNames).apply(lambda y: y['humanResults'].values.argmax())
    mStrat = modelPreds.groupby(indxNames).apply(lambda y: y['modelResults'].values.argmax())
    matches = (hStrat == mStrat).value_counts()
    return(matches)

# %%
def getNMatches(dfRow):
    getModelingResults =  EvaluateOverloadedSignaler(humanResults, returnStrategyBreakdown = True)
    modelStrategyPDF = getModelingResults(alpha=dfRow.index.get_level_values('alpha')[0], 
                                      valueOfReward=dfRow.index.get_level_values('valueOfReward')[0], 
                                      signalMeaningPrior=dfRow.index.get_level_values('signalTypePriors')[0], 
                                      costOfSignal = 0, 
                                      costOfPunishment = 0)
    stratMatches = getMatchingStrategies(modelStrategyPDF)
    return(stratMatches)

# %% [markdown]
# ## Look at best parameters inA# each evaluation grid

# %%
byAlphaMod05 = mod_meaning05.loc[(mod_meaning05.index.get_level_values('valueOfReward')==1.0) & 
         (mod_meaning05.index.get_level_values('costOfNonReward')==-.1) &
        (mod_meaning05.index.get_level_values('costOfSignal')==.01)]

# %%
x = mod_meaning05.loc[(mod_meaning05.index.get_level_values('valueOfReward')==5.0) & 
         (mod_meaning05.index.get_level_values('costOfNonReward')==-5.0) &
        (mod_meaning05.index.get_level_values('costOfSignal')==.01)]

# %%
x.groupby(x.index.names).apply(getNMatches)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-136770191f19> in <module>()
# ----> 1 x.groupby(x.index.names).apply(getNMatches)
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     916         with option_context('mode.chained_assignment', None):
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#     920
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# <ipython-input-5-7f4dd67c0836> in getNMatches(dfRow)
#       5                                       signalMeaningPrior=dfRow.index.get_level_values('signalTypePriors')[0],
#       6                                       costOfSignal = 0,
# ----> 7                                       costOfPunishment = 0)
#       8     stratMatches = getMatchingStrategies(modelStrategyPDF)
#       9     return(stratMatches)
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/evaluateMisyak_FullExperimentalConditions.py in __call__(self, alpha, valueOfReward, signalMeaningPrior, costOfPunishment, costOfSignal)
#      38         misyakExperimentConditions = list(it.product([1,2], [1,2], [0,1], [1,2])) #tokens, axes, show shadow, rewards - 16 experimental conditions
#      39         for condition in misyakExperimentConditions:
# ---> 40             results.loc[condition,'modelResults'] =  self.getStrategyDistribution(condition, setupTrial)
#      41
#      42         if self.returnStrategyBreakdown:
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/evaluateMisyak_FullExperimentalConditions.py in getStrategyDistribution(self, conditionTuple, setupTrialFunction)
#      68
#      69     def getStrategyDistribution(self, conditionTuple, setupTrialFunction):
# ---> 70         signalDistribution = self.getSignalPDF(conditionTuple, setupTrialFunction)
#      71         pAvoid = self.getProbabilityAvoidStrategy(signalDistribution, conditionTuple)
#      72         pMixed = self.getProbabilityMixedStrategy(signalDistribution, conditionTuple)
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/evaluateMisyak_FullExperimentalConditions.py in getSignalPDF(self, conditionTuple, setupTrialFunction)
#      82         nRewards = conditionTuple[3]
#      83         #print("tokens", ntokens, "axes", axes, "showShadow", showShadow, 'nRewards', nRewards)
# ---> 84         _,_, signaler = setupTrialFunction(ntokens, axes, showShadow, nRewards)
#      85
#      86         if nRewards == 1:
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/../../../Environments/Misyak/setupInference_Misyak.py in __call__(self, nTokens, nAxes, showShadow, nRewards)
#      37             constructMind=getMind,
#      38             getSignalerZero=getSignalerZero,
# ---> 39             signalCategoryPrior=self.signalMeaningPrior)
#      40
#      41         getSignalerOne = SignalerOne(alpha=self.alpha,
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/../../../Algorithms/ImaginedWe/OverloadedReceiver.py in __init__(self, commonGroundDictionary, constructMind, getSignalerZero, signalCategoryPrior)
#      86 class ReceiverZero(object):
#      87     def __init__(self, commonGroundDictionary, constructMind, getSignalerZero, signalCategoryPrior):
# ---> 88         self.mindPrior = constructMind(commonGroundDictionary)
#      89         self.getSignalLikelihood = getSignalerZero
#      90         self.signalCategoryPrior = signalCategoryPrior
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/../../../Algorithms/ImaginedWe/mindConstruction.py in __call__(self, mindSpaceDictionary)
#      34
#      35         #getMindForCondition = lambda condition: self.getConditionMind(condition, mindSpaceDictionary)
# ---> 36         mindProbabilitySeries = jointMindSpace.groupby(jointMindSpace.index.names).apply(lambda x: self.getConditionMind(x, mindSpaceDictionary))
#      37         mindProbability = pd.DataFrame(normalizeValuesPdSeries(mindProbabilitySeries))
#      38         mindProbability.rename(columns={0 : NC.P_MIND}, inplace=True)
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     916         with option_context('mode.chained_assignment', None):
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#     920
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/../../../Algorithms/ImaginedWe/mindConstruction.py in <lambda>(x)
#      34
#      35         #getMindForCondition = lambda condition: self.getConditionMind(condition, mindSpaceDictionary)
# ---> 36         mindProbabilitySeries = jointMindSpace.groupby(jointMindSpace.index.names).apply(lambda x: self.getConditionMind(x, mindSpaceDictionary))
#      37         mindProbability = pd.DataFrame(normalizeValuesPdSeries(mindProbabilitySeries))
#      38         mindProbability.rename(columns={0 : NC.P_MIND}, inplace=True)
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/../../../Algorithms/ImaginedWe/mindConstruction.py in getConditionMind(self, oneMindCondition, mindSpace)
#      55
#      56         actionSpace = mindSpace[NC.ACTIONS]
# ---> 57         conditionalActionPDF = self.getActionProbability(actionSpace, world, goal)
#      58
#      59         worldProb = worldPDF.loc[world].values[0]
#
# ~/Documents/Research/OverloadedSignaling/Environments/Misyak/eval/../../../Environments/Misyak/misyakConstruction.py in __call__(self, actionSpace, world, goal)
#      84             numberOfOccurances = actionSpaceDF[NC.P_ACTION].value_counts().loc[maxUtility]
#      85             getConditionProbability = lambda x: np.where(x == maxUtility, 1.0/numberOfOccurances, 0.)
# ---> 86             actionSpaceDF[NC.P_ACTION] = actionSpaceDF.groupby(actionSpaceDF.index.names).transform(getConditionProbability)
#      87         return(actionSpaceDF)
#      88
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in transform(self, func, *args, **kwargs)
#    4432                 result = getattr(self, func)(*args, **kwargs)
#    4433         else:
# -> 4434             return self._transform_general(func, *args, **kwargs)
#    4435
#    4436         # a reduction transform
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _transform_general(self, func, *args, **kwargs)
#    4377
#    4378         path = None
# -> 4379         for name, group in gen:
#    4380             object.__setattr__(group, 'name', name)
#    4381
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in get_iterator(self, data, axis)
#    2226         splitter = self._get_splitter(data, axis=axis)
#    2227         keys = self._get_group_keys()
# -> 2228         for key, (i, group) in zip(keys, splitter):
#    2229             yield key, group
#    2230
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in __iter__(self)
#    5053             #     raise AssertionError('Start %s must be less than end %s'
#    5054             #                          % (str(start), str(end)))
# -> 5055             yield i, self._chop(sdata, slice(start, end))
#    5056
#    5057     def _get_sorted_data(self):
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _chop(self, sdata, slice_obj)
#    5092     def _chop(self, sdata, slice_obj):
#    5093         if self.axis == 0:
# -> 5094             return sdata.iloc[slice_obj]
#    5095         else:
#    5096             return sdata._slice(slice_obj, axis=1)  # .loc[:, slice_obj]
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2078
#    2079         if isinstance(key, slice):
# -> 2080             return self._get_slice_axis(key, axis=axis)
#    2081
#    2082         if isinstance(key, list):
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    2048         slice_obj = self._convert_slice_indexer(slice_obj, axis)
#    2049         if isinstance(slice_obj, slice):
# -> 2050             return self._slice(slice_obj, axis=axis, kind='iloc')
#    2051         else:
#    2052             return self.obj._take(slice_obj, axis=axis)
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/indexing.py in _slice(self, obj, axis, kind)
#     148         if axis is None:
#     149             axis = self.axis
# --> 150         return self.obj._slice(obj, axis=axis, kind=kind)
#     151
#     152     def _get_setitem_indexer(self, key):
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/generic.py in _slice(self, slobj, axis, kind)
#    2588         """
#    2589         axis = self._get_block_manager_axis(axis)
# -> 2590         result = self._constructor(self._data.get_slice(slobj, axis=axis))
#    2591         result = result.__finalize__(self)
#    2592
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/internals.py in get_slice(self, slobj, axis)
#    3880
#    3881         new_axes = list(self.axes)
# -> 3882         new_axes[axis] = new_axes[axis][slobj]
#    3883
#    3884         bm = self.__class__(new_blocks, new_axes, do_integrity_check=False)
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/indexes/multi.py in __getitem__(self, key)
#    1584             return MultiIndex(levels=self.levels, labels=new_labels,
#    1585                               names=self.names, sortorder=sortorder,
# -> 1586                               verify_integrity=False)
#    1587
#    1588     @Appender(_index_shared_docs['take'] % _index_doc_kwargs)
#
# ~/miniconda3/envs/cogsci/lib/python3.5/site-packages/pandas/core/indexes/multi.py in __new__(cls, levels, labels, sortorder, names, dtype, copy, name, verify_integrity, _set_identity)
#     221         if len(levels) != len(labels):
#     222             raise ValueError('Length of levels and labels must be the same.')
# --> 223         if len(levels) == 0:
#     224             raise ValueError('Must pass non-zero number of levels/labels')
#     225
#
# KeyboardInterrupt:

# %%
byAlphaMod05
# Out:
#                                                                    keyConditionRMSE  \
# alpha signalTypePriors valueOfReward costOfNonReward costOfSignal
# 2.0   0.5              1.0           -0.1            0.01                  0.180559
# 3.0   0.5              1.0           -0.1            0.01                  0.160112
# 4.0   0.5              1.0           -0.1            0.01                  0.146678
# 5.0   0.5              1.0           -0.1            0.01                  0.139401
# 6.0   0.5              1.0           -0.1            0.01                  0.135834
# 7.0   0.5              1.0           -0.1            0.01                  0.134321
# 8.0   0.5              1.0           -0.1            0.01                  0.134117
# 9.0   0.5              1.0           -0.1            0.01                  0.134915
# 10.0  0.5              1.0           -0.1            0.01                  0.136563
#
#                                                                    keyConditionVariance  \
# alpha signalTypePriors valueOfReward costOfNonReward costOfSignal
# 2.0   0.5              1.0           -0.1            0.01                      0.032602
# 3.0   0.5              1.0           -0.1            0.01                      0.025636
# 4.0   0.5              1.0           -0.1            0.01                      0.021514
# 5.0   0.5              1.0           -0.1            0.01                      0.019433
# 6.0   0.5              1.0           -0.1            0.01                      0.018451
# 7.0   0.5              1.0           -0.1            0.01                      0.018042
# 8.0   0.5              1.0           -0.1            0.01                      0.017987
# 9.0   0.5              1.0           -0.1            0.01                      0.018202
# 10.0  0.5              1.0           -0.1            0.01                      0.018649
#
#                                                                    totalRMSE  \
# alpha signalTypePriors valueOfReward costOfNonReward costOfSignal
# 2.0   0.5              1.0           -0.1            0.01           0.361439
# 3.0   0.5              1.0           -0.1            0.01           0.359882
# 4.0   0.5              1.0           -0.1            0.01           0.360289
# 5.0   0.5              1.0           -0.1            0.01           0.360409
# 6.0   0.5              1.0           -0.1            0.01           0.359409
# 7.0   0.5              1.0           -0.1            0.01           0.357448
# 8.0   0.5              1.0           -0.1            0.01           0.354934
# 9.0   0.5              1.0           -0.1            0.01           0.352206
# 10.0  0.5              1.0           -0.1            0.01           0.349483
#
#                                                                    totalVariance
# alpha signalTypePriors valueOfReward costOfNonReward costOfSignal
# 2.0   0.5              1.0           -0.1            0.01               0.130638
# 3.0   0.5              1.0           -0.1            0.01               0.129515
# 4.0   0.5              1.0           -0.1            0.01               0.129808
# 5.0   0.5              1.0           -0.1            0.01               0.129895
# 6.0   0.5              1.0           -0.1            0.01               0.129175
# 7.0   0.5              1.0           -0.1            0.01               0.127769
# 8.0   0.5              1.0           -0.1            0.01               0.125978
# 9.0   0.5              1.0           -0.1            0.01               0.124049
# 10.0  0.5              1.0           -0.1            0.01               0.122139

# %%
matchGrid05  = byAlphaMod05.groupby(byAlphaMod05.index.names).apply(getNMatches)
matchGrid05
# Out:
# alpha  signalTypePriors  valueOfReward  costOfNonReward  costOfSignal
# 2.0    0.5               1.0            -0.1             0.01          False     9
#                                                                        True      7
# 3.0    0.5               1.0            -0.1             0.01          False     9
#                                                                        True      7
# 4.0    0.5               1.0            -0.1             0.01          False     9
#                                                                        True      7
# 5.0    0.5               1.0            -0.1             0.01          True      9
#                                                                        False     7
# 6.0    0.5               1.0            -0.1             0.01          True      9
#                                                                        False     7
# 7.0    0.5               1.0            -0.1             0.01          True      9
#                                                                        False     7
# 8.0    0.5               1.0            -0.1             0.01          True     10
#                                                                        False     6
# 9.0    0.5               1.0            -0.1             0.01          True      9
#                                                                        False     7
# 10.0   0.5               1.0            -0.1             0.01          True      8
#                                                                        False     8
# dtype: int64

# %%
byAlphaMeaning = modMeaning.loc[(modMeaning.index.get_level_values('signalTypePriors')== .55) &
                                (modMeaning.index.get_level_values('valueOfReward')== 5.0) & 
                                 (modMeaning.index.get_level_values('costOfNonReward')==-.5) &
                                (modMeaning.index.get_level_values('costOfSignal')==.01)]

# %%
modMeaning
# Out:
#                                                                    keyConditionRMSE  \
# alpha signalTypePriors valueOfReward costOfNonReward costOfSignal
# 2.0   0.50             5             -1.0            0.01                  0.134194
#                                                      0.05                  0.139579
#                                                      0.10                  0.146881
#                                      -0.5            0.01                  0.130788
#                                                      0.05                  0.136563
#                                                      0.10                  0.144337
#                                      -0.1            0.01                  0.128527
#                                                      0.05                  0.134593
#                                                      0.10                  0.142719
#       0.55             5             -1.0            0.01                  0.113960
#                                                      0.05                  0.120943
#                                                      0.10                  0.130121
#                                      -0.5            0.01                  0.114396
#                                                      0.05                  0.121376
#                                                      0.10                  0.130546
#                                      -0.1            0.01                  0.114944
#                                                      0.05                  0.121902
#                                                      0.10                  0.131044
#       0.60             5             -1.0            0.01                  0.133658
#                                                      0.05                  0.138805
#                                                      0.10                  0.145778
#                                      -0.5            0.01                  0.132697
#                                                      0.05                  0.137891
#                                                      0.10                  0.144918
#                                      -0.1            0.01                  0.131940
#                                                      0.05                  0.137172
#                                                      0.10                  0.144243
#       0.65             5             -1.0            0.01                  0.163101
#                                                      0.05                  0.165954
#                                                      0.10                  0.170043
# ...                                                                             ...
# 8.0   0.50             5             -0.1            0.01                  0.229937
#                                                      0.05                  0.227822
#                                                      0.10                  0.226231
#       0.55             5             -1.0            0.01                  0.185985
#                                                      0.05                  0.188375
#                                                      0.10                  0.195977
#                                      -0.5            0.01                  0.176599
#                                                      0.05                  0.180644
#                                                      0.10                  0.191155
#                                      -0.1            0.01                  0.168585
#                                                      0.05               0.106580
#                                                      0.10               0.103978
#       0.55             5             -1.0            0.01               0.058337
#                                                      0.05               0.056865
#                                                      0.10               0.056583
#                                      -0.5            0.01               0.056538
#                                                      0.05               0.055603
#                                                      0.10               0.055857
#                                      -0.1            0.01               0.055507
#                                                      0.05               0.054952
#                                                      0.10               0.055595
#       0.60             5             -1.0            0.01               0.050358
#                                                      0.05               0.051762
#                                                      0.10               0.054691
#                                      -0.5            0.01               0.050574
#                                                      0.05               0.051885
#                                                      0.10               0.054744
#                                      -0.1            0.01               0.050791
#                                                      0.05               0.052012
#                                                      0.10               0.054803
#       0.65             5             -1.0            0.01               0.055654
#                                                      0.05               0.055689
#                                                      0.10               0.056414
#                                      -0.5            0.01               0.055579
#                                                      0.05               0.055592
#                                                      0.10               0.056400
#                                      -0.1            0.01               0.055660
#                                                      0.05               0.055599
#                                                      0.10               0.056436
#
# [252 rows x 4 columns]

# %%
matchGrid_m = byAlphaMeaning.groupby(byAlphaMeaning.index.names).apply(getNMatches)

# %%
matchGrid_m
# Out:
#                                                                    True   \
# alpha signalTypePriors valueOfReward costOfNonReward costOfSignal
# 2.0   0.55             5             -0.5            0.01             11
# 3.0   0.55             5             -0.5            0.01             11
# 4.0   0.55             5             -0.5            0.01             10
# 5.0   0.55             5             -0.5            0.01             11
# 6.0   0.55             5             -0.5            0.01             12
# 7.0   0.55             5             -0.5            0.01             12
# 8.0   0.55             5             -0.5            0.01             12
#
#                                                                    False
# alpha signalTypePriors valueOfReward costOfNonReward costOfSignal
# 2.0   0.55             5             -0.5            0.01              5
# 3.0   0.55             5             -0.5            0.01              5
# 4.0   0.55             5             -0.5            0.01              6
# 5.0   0.55             5             -0.5            0.01              5
# 6.0   0.55             5             -0.5            0.01              4
# 7.0   0.55             5             -0.5            0.01              4
# 8.0   0.55             5             -0.5            0.01              4

# %%
tuneGrid828.loc[(tuneGrid828.index.get_level_values('signalTypePriors')== .55) &
                                (tuneGrid828.index.get_level_values('alpha') > 6.0)&
                                (tuneGrid828.index.get_level_values('costOfSignal') == 0)]['keyConditionRMSE'].mean()
# Out:
# 0.12102673135340608

# %%
tuneGrid828.loc[(tuneGrid828.index.get_level_values('signalTypePriors')== .55) &
                                (tuneGrid828.index.get_level_values('alpha') > 6.0)&
                                (tuneGrid828.index.get_level_values('costOfSignal') == 0.1)]['keyConditionRMSE'].mean()
# Out:
# 0.21242641102668527

# %% [markdown]
# # Example Strategy Distribution for Specific Parameter Set

# %%
from evaluateMisyak_FullExperimentalConditions import EvaluateOverloadedSignaler

# %%
alpha = 3
reward = 5
prior = .5
sigCost = 0.01
scorpion = -0.1

# %%
getModelingResults =  EvaluateOverloadedSignaler(humanResults, returnStrategyBreakdown = True)
modelPredictions = getModelingResults(alpha=alpha, 
                                      valueOfReward=reward, 
                                      signalMeaningPrior=prior, 
                                      costOfSignal = sigCost, 
                                      costOfPunishment = scorpion)

# %%
modelPredictions.loc[(1,2,0,2)]
# Out:
#           humanResults  modelResults
# strategy
# avoid         0.234375      0.287850
# mixed         0.000000      0.000000
# open          0.765625      0.575699
# silent        0.000000      0.136451

# %%
getMatchingStrategies(modelPredictions)
# Out:
# True     9
# False    7
# dtype: int64

# %% [markdown]
# # Plot Strategy Grid Success

# %%
#plotting hyperparameters
figureSize = (25,18)
horizontalSpaceBetweenSubplots = .45
legendColors = {'avoid' : 'thistle', 'open':'royalblue' ,'silent':'gold','mixed':'lightsalmon'}
hatch = {'twoToken':'n', 'twoToken_goto':'//','inversion':'n','inversion_goto':'//', 'wall':'n','wall_goto':'//', 'oneAx':'n', 'oneAx_goto':'//'}

# %%
#dataframe to plot
dataframeName = modelPredictions
dataFrameRowLength = 4
dataFrameColLength = 4

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
def drawPerformanceBarPlot(dfCondition,  axForDraw, nConditions = 4, hatches = None, barWidth = .35):
    N = nConditions
    ind = np.arange(N)  # the x locations for the groups
    width = barWidth      # the width of the bars
    #mpl.rcParams['hatch.color'] = 'grey'
    
    labels = dfCondition.columns
    avoid = dfCondition.loc['avoid']
    openCondition = dfCondition.loc['open']
    silent = dfCondition.loc['silent']
    mixed = dfCondition.loc['mixed']
    
    cols = ['thistle','thistle','royalblue', 'royalblue','gold', 'gold','lightsalmon', 'lightsalmon']
    hatchPattern = ['n', '//', 'n', '//', 'n', '//', 'n','//']

    axForDraw.bar(labels, openCondition, width, label='Open', color = 'royalblue')
    axForDraw.bar(labels, avoid, width, bottom = openCondition, label='Avoid', color = 'thistle')
    axForDraw.bar(labels, silent, width, bottom=openCondition+avoid, label='Silent', color = 'gold')
    axForDraw.bar(labels, mixed, width, bottom=openCondition+avoid+silent, label='Mixed', color = 'lightsalmon')
    
    axForDraw.set_yticks([0,.5,1])
    axForDraw.set_xticks([])

# %%
fig = plt.figure(figsize=figureSize)
numRows = dataFrameRowLength
numColumns = dataFrameColLength
plotCounter = 1

for condition, grp in dataframeName.groupby(['n_tokens','n_axes','show_imprints','n_bananas']):
    grp.index = grp.index.droplevel(['n_tokens','n_axes','show_imprints','n_bananas'])
    #for signalTypePriors, group in grp.groupby('signalTypePriors'):

    keyConditions = [(2,2,1,2),(1,2,1,2),(1,1,1,2),(1,2,0,2)]
    #subplot axis labels
    axForDraw = fig.add_subplot(numRows, numColumns, plotCounter)
    axForDraw.set_title('condition: {}'.format(condition))
    if condition in keyConditions:
        axForDraw.set_title('condition: {}'.format(condition), color = 'red')
    axForDraw.set_ylim(0, 1)

    #draw subplot
    drawPerformanceBarPlot(grp, axForDraw, 2)

    plotCounter += 1

#Title
plt.suptitle('Modeling and Human Strategy Comparison')

#legend
legend_dict = legendColors
patchList = []
trialList = ["avoid", 'mixed', 'open', 'silent']
for key in trialList:
    data_key = mpatches.Patch(color=legend_dict[key], label=key)
    patchList.append(data_key)
plt.legend(handles=patchList, loc='best')

#adjust horizontal spacing of subplots
fig.subplots_adjust(wspace=.2)

plt.show()

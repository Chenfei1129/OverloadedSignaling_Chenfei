# %%
import sys
import numpy as np
import pandas as pd
sys.path.append('/home/stacyste/Documents/Research/OverloadedSignaling/Simulations')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_pickle('./simulation_checkAgainstFVByItemSim.pkl')

# %%
df
# Out:
#      signalerLocation receiverLocation        intention  \
# 0              (4, 0)           (4, 7)     green circle
# 1              (4, 0)           (4, 7)   green triangle
# 2              (4, 0)           (4, 7)  purple triangle
# 3              (4, 0)           (4, 7)     green circle
# 4              (4, 0)           (4, 7)  purple triangle
# 5              (4, 0)           (4, 7)   green triangle
# 6              (4, 0)           (4, 7)     red triangle
# 7              (4, 0)           (4, 7)     red triangle
# 8              (4, 0)           (4, 7)  purple triangle
# 9              (4, 0)           (4, 7)  purple triangle
# 10             (4, 0)           (4, 7)     green circle
# 11             (4, 0)           (4, 7)    purple circle
# 12             (4, 0)           (4, 7)   green triangle
# 13             (4, 0)           (4, 7)       red circle
# 14             (4, 0)           (4, 7)       red circle
# 15             (4, 0)           (4, 7)  purple triangle
# 16             (4, 0)           (4, 7)    purple square
# 17             (4, 0)           (4, 7)     red triangle
# 18             (4, 0)           (4, 7)       red square
# 19             (4, 0)           (4, 7)  purple triangle
# 20             (4, 0)           (4, 7)       red square
# 21             (4, 0)           (4, 7)       red circle
# 22             (4, 0)           (4, 7)   green triangle
# 23             (4, 0)           (4, 7)    purple square
# 24             (4, 0)           (4, 7)    purple circle
# 25             (4, 0)           (4, 7)   green triangle
# 26             (4, 0)           (4, 7)  purple triangle
# 27             (4, 0)           (4, 7)     green square
# 28             (4, 0)           (4, 7)   green triangle
# 29             (4, 0)           (4, 7)   green triangle
# ...               ...              ...              ...
# 1971           (4, 0)           (4, 7)     green circle
# 1972           (4, 0)           (4, 7)       red square
# 1973           (4, 0)           (4, 7)    purple square
# 1974           (4, 0)           (4, 7)       red circle
# 1975           (4, 0)           (4, 7)   green triangle
# 1976           (4, 0)           (4, 7)   green triangle
# 1977           (4, 0)           (4, 7)    purple square
# 1978           (4, 0)           (4, 7)    purple circle
# 1979           (4, 0)           (4, 7)    purple square
# 1980           (4, 0)           (4, 7)    purple circle
# 1981           (4, 0)           (4, 7)  purple triangle
# 1982           (4, 0)           (4, 7)    purple square
# 1983           (4, 0)           (4, 7)     green square
# 1984           (4, 0)           (4, 7)     red triangle
# 1985           (4, 0)           (4, 7)       red square
# 1986           (4, 0)           (4, 7)       red square
# 1987           (4, 0)           (4, 7)   green triangle
# 1988           (4, 0)           (4, 7)    purple circle
# 1989           (4, 0)           (4, 7)     green square
# 1990           (4, 0)           (4, 7)    purple circle
# 1991           (4, 0)           (4, 7)     green circle
# 1992           (4, 0)           (4, 7)       red square
# 1993           (4, 0)           (4, 7)    purple circle
# 1994           (4, 0)           (4, 7)     green square
# 1995           (4, 0)           (4, 7)    purple circle
# 1996           (4, 0)           (4, 7)  purple triangle
# 1997           (4, 0)           (4, 7)   green triangle
# 1998           (4, 0)           (4, 7)     green square
# 1999           (4, 0)           (4, 7)    purple square
# 2000           (4, 0)           (4, 7)    purple circle
#
#                                          signalSpace  \
# 0     [purple, green, red, circle, square, triangle]
# 1     [purple, green, red, circle, square, triangle]
# 2     [purple, green, red, circle, square, triangle]
# 3     [purple, green, red, circle, square, triangle]
# 4     [purple, green, red, circle, square, triangle]
# 5     [purple, green, red, circle, square, triangle]
# 6     [purple, green, red, circle, square, triangle]
# 7     [purple, green, red, circle, square, triangle]
# 8     [purple, green, red, circle, square, triangle]
# 9     [purple, green, red, circle, square, triangle]
# 10    [purple, green, red, circle, square, triangle]
# 11    [purple, green, red, circle, square, triangle]
# 12                         [triangle, purple, green]
# 13                             [red, circle, square]
# 14    [purple, green, red, circle, square, triangle]
# 15    [purple, green, red, circle, square, triangle]
# 16           [circle, red, triangle, purple, square]
# 17    [purple, green, red, circle, square, triangle]
# 18           [circle, red, triangle, purple, square]
# 19    [purple, green, red, circle, square, triangle]
# 20    [purple, green, red, circle, square, triangle]
# 21    [purple, green, red, circle, square, triangle]
# 22    [purple, green, red, circle, square, triangle]
# 23    [purple, green, red, circle, square, triangle]
# 24    [purple, green, red, circle, square, triangle]
# 25         [triangle, circle, green, purple, square]
# 26                    [red, triangle, green, purple]
# 27    [purple, green, red, circle, square, triangle]
# 28    [purple, green, red, circle, square, triangle]
# 29            [red, triangle, purple, green, square]
# ...                                              ...
# 1971  [purple, green, red, circle, square, triangle]
# 1972                         [red, triangle, square]
# 1973            [circle, red, green, purple, square]
# 1974  [purple, green, red, circle, square, triangle]
# 1975  [purple, green, red, circle, square, triangle]
# 1976  [purple, green, red, circle, square, triangle]
# 1977  [purple, green, red, circle, square, triangle]
# 1978                           [red, circle, purple]
# 1979  [purple, green, red, circle, square, triangle]
# 1980  [purple, green, red, circle, square, triangle]
# 1981          [red, triangle, green, purple, square]
# 1982  [purple, green, red, circle, square, triangle]
# 1983               [triangle, green, purple, square]
# 1984                 [circle, red, triangle, purple]
# 1985         [circle, red, triangle, purple, square]
# 1986                 [red, triangle, purple, square]
# 1987  [purple, green, red, circle, square, triangle]
# 1988  [purple, green, red, circle, square, triangle]
# 1989  [purple, green, red, circle, square, triangle]
# 1990  [purple, green, red, circle, square, triangle]
# 1991  [purple, green, red, circle, square, triangle]
# 1992  [purple, green, red, circle, square, triangle]
# 1993  [purple, green, red, circle, square, triangle]
# 1994  [purple, green, red, circle, square, triangle]
# 1995                 [circle, green, purple, square]
# 1996       [circle, triangle, green, purple, square]
# 1997  [purple, green, red, circle, square, triangle]
# 1998  [purple, green, red, circle, square, triangle]
# 1999  [purple, green, red, circle, square, triangle]
# 2000                 [red, triangle, circle, purple]
#
#                                        targetDictionary     IW_N_sChoice  \
# 0     {(0, 1): 'purple circle', (0, 6): 'red square'...     green circle
# 1     {(6, 3): 'red circle', (3, 2): 'purple triangl...         triangle
# 2     {(2, 6): 'purple triangle', (1, 3): 'green squ...         triangle
# 3     {(3, 5): 'red triangle', (8, 0): 'red square',...            green
# 4     {(8, 8): 'purple square', (6, 5): 'green squar...         triangle
# 5     {(7, 4): 'green triangle', (8, 6): 'green circ...         triangle
# 6     {(8, 1): 'red triangle', (8, 3): 'green triang...     red triangle
# 7     {(0, 3): 'purple square', (8, 5): 'green circl...         triangle
# 8     {(3, 8): 'red triangle', (6, 4): 'red circle',...  purple triangle
# 9     {(8, 1): 'green circle', (0, 3): 'purple circl...           purple
# 10    {(4, 9): 'purple circle', (4, 6): 'green trian...     green circle
# 11    {(2, 0): 'green square', (7, 5): 'green triang...    purple circle
# 12    {(7, 5): 'green triangle', (3, 9): 'purple tri...            green
# 13         {(7, 4): 'red circle', (4, 8): 'red square'}           circle
# 14    {(6, 3): 'green square', (1, 5): 'red square',...           circle
# 15    {(7, 3): 'purple circle', (2, 6): 'green circl...  purple triangle
# 16    {(7, 4): 'purple triangle', (6, 1): 'purple ci...           square
# 17    {(1, 2): 'green circle', (8, 7): 'red triangle...              red
# 18    {(5, 1): 'purple square', (6, 4): 'red square'...           square
# 19    {(3, 8): 'purple square', (0, 1): 'green squar...         triangle
# 20    {(8, 1): 'purple circle', (8, 8): 'green trian...              red
# 21    {(1, 2): 'purple square', (7, 4): 'green trian...       red circle
# 22    {(1, 2): 'green square', (5, 1): 'red triangle...         triangle
# 23    {(8, 1): 'purple triangle', (3, 2): 'green tri...           purple
# 24    {(7, 3): 'green triangle', (8, 3): 'purple squ...    purple circle
# 25    {(1, 2): 'green triangle', (6, 2): 'purple cir...   green triangle
# 26    {(0, 9): 'red triangle', (4, 5): 'purple trian...           purple
# 27    {(3, 3): 'red circle', (2, 9): 'green triangle...     green square
# 28    {(3, 2): 'green triangle', (4, 9): 'red square...   green triangle
# 29    {(0, 6): 'red square', (0, 3): 'green triangle...   green triangle
# ...                                                 ...              ...
# 1971  {(4, 5): 'red square', (7, 0): 'green circle',...     green circle
# 1972     {(5, 9): 'red triangle', (8, 2): 'red square'}       red square
# 1973  {(3, 8): 'purple circle', (7, 4): 'red circle'...    purple square
# 1974  {(1, 2): 'red square', (0, 0): 'green triangle...              red
# 1975  {(4, 4): 'green square', (8, 2): 'purple circl...   green triangle
# 1976  {(3, 8): 'purple triangle', (6, 3): 'red squar...            green
# 1977  {(6, 4): 'purple triangle', (2, 9): 'green tri...    purple square
# 1978    {(1, 2): 'red circle', (7, 8): 'purple circle'}           circle
# 1979  {(2, 7): 'red circle', (1, 3): 'red triangle',...           purple
# 1980  {(3, 8): 'red circle', (7, 3): 'green square',...    purple circle
# 1981  {(2, 8): 'purple triangle', (5, 2): 'green tri...           purple
# 1982  {(3, 1): 'purple circle', (2, 3): 'red triangl...           purple
# 1983  {(8, 3): 'green triangle', (3, 4): 'purple tri...            green
# 1984  {(0, 1): 'purple circle', (8, 5): 'red triangle'}         triangle
# 1985  {(4, 5): 'red square', (4, 1): 'purple triangl...              red
# 1986  {(3, 7): 'red square', (6, 6): 'purple triangle'}           square
# 1987  {(5, 6): 'red circle', (3, 3): 'green square',...            green
# 1988  {(8, 1): 'green circle', (5, 6): 'red circle',...           purple
# 1989  {(2, 8): 'purple triangle', (2, 5): 'green squ...            green
# 1990  {(1, 5): 'green circle', (1, 8): 'red square',...    purple circle
# 1991  {(6, 4): 'green square', (3, 3): 'purple squar...            green
# 1992  {(5, 7): 'red triangle', (8, 6): 'red square',...              red
# 1993  {(1, 3): 'red triangle', (2, 9): 'green triang...    purple circle
# 1994  {(0, 1): 'green circle', (0, 8): 'green triang...           square
# 1995  {(3, 3): 'purple circle', (8, 4): 'green square'}    purple circle
# 1996  {(6, 3): 'purple triangle', (2, 3): 'purple ci...  purple triangle
# 1997  {(2, 7): 'green circle', (3, 8): 'green square...            green
# 1998  {(2, 7): 'red square', (1, 3): 'purple circle'...     green square
# 1999  {(2, 0): 'red triangle', (6, 9): 'red square',...           purple
# 2000  {(1, 2): 'red circle', (8, 1): 'red triangle',...           circle
#
#          IW_N_rChoice  IW_N_sAchievesGoal  IW_N_rAchievesGoal  \
# 0                None                True               False
# 1      green triangle               False                True
# 2     purple triangle               False                True
# 3        green circle               False                True
# 4        red triangle               False               False
# 5      green triangle               False                True
# 6                None                True               False
# 7        red triangle               False                True
# 8                None                True               False
# 9     purple triangle               False                True
# 10               None                True               False
# 11               None                True               False
# 12     green triangle               False                True
# 13         red circle               False                True
# 14         red circle               False                True
# 15               None                True               False
# 16      purple square               False                True
# 17       red triangle               False                True
# 18         red square               False                True
# 19    purple triangle               False                True
# 20         red square               False                True
# 21               None                True               False
# 22     green triangle               False                True
# 23      purple square               False                True
# 24               None                True               False
# 25               None                True               False
# 26    purple triangle               False                True
# 27               None                True               False
# 28               None                True               False
# 29               None                True               False
# ...               ...                 ...                 ...
# 1971             None                True               False
# 1972             None                True               False
# 1973             None                True               False
# 1974       red circle               False                True
# 1975             None                True               False
# 1976   green triangle               False                True
# 1977             None                True               False
# 1978    purple circle               False                True
# 1979    purple square               False                True
# 1980             None                True               False
# 1981  purple triangle               False                True
# 1982    purple square               False                True
# 1983     green square               False                True
# 1984     red triangle               False                True
# 1985       red square               False                True
# 1986       red square               False                True
# 1987   green triangle               False                True
# 1988    purple circle               False                True
# 1989     green square               False                True
# 1990             None                True               False
# 1991     green circle               False                True
# 1992     red triangle               False               False
# 1993             None                True               False
# 1994     green square               False                True
# 1995             None                True               False
# 1996             None                True               False
# 1997   green triangle               False                True
# 1998             None                True               False
# 1999    purple square               False                True
# 2000    purple circle               False                True
#
#       IW_N_goalAchieved         ...           IW_S1R1_utility  \
# 0                  True         ...                         1
# 1                  True         ...                         4
# 2                  True         ...                         5
# 3                  True         ...                         4
# 4                 False         ...                         4
# 5                  True         ...                         2
# 6                  True         ...                         3
# 7                  True         ...                         5
# 8                  True         ...                         2
# 9                  True         ...                         4
# 10                 True         ...                         6
# 11                 True         ...                         1
# 12                 True         ...                         3
# 13                 True         ...                         2
# 14                 True         ...                         6
# 15                 True         ...                         2
# 16                 True         ...                         5
# 17                 True         ...                         4
# 18                 True         ...                         3
# 19                 True         ...                         4
# 20                 True         ...                         6
# 21                 True         ...                         4
# 22                 True         ...                         2
# 23                 True         ...                         2
# 24                 True         ...                         1
# 25                 True         ...                         3
# 26                 True         ...                         6
# 27                 True         ...                         7
# 28                 True         ...                         5
# 29                 True         ...                         1
# ...                 ...         ...                       ...
# 1971               True         ...                         5
# 1972               True         ...                         2
# 1973               True         ...                         5
# 1974               True         ...                         4
# 1975               True         ...                         5
# 1976               True         ...                         4
# 1977               True         ...                         1
# 1978               True         ...                         4
# 1979               True         ...                         6
# 1980               True         ...                         3
# 1981               True         ...                         5
# 1982               True         ...                         2
# 1983               True         ...                         6
# 1984               True         ...                         2
# 1985               True         ...                         6
# 1986               True         ...                         7
# 1987               True         ...                         2
# 1988               True         ...                         1
# 1989               True         ...                         4
# 1990               True         ...                         5
# 1991               True         ...                         3
# 1992              False         ...                         3
# 1993               True         ...                         6
# 1994               True         ...                         5
# 1995               True         ...                         4
# 1996               True         ...                         3
# 1997               True         ...                         5
# 1998               True         ...                         4
# 1999               True         ...                         5
# 2000               True         ...                         3
#
#      RSA_S1R1_sChoice RSA_S1R1_rChoice  RSA_S1R1_sAchievesGoal  \
# 0        green circle             None                    True
# 1               green   green triangle                   False
# 2     purple triangle             None                    True
# 3        green circle             None                    True
# 4              purple    purple square                   False
# 5            triangle   green triangle                   False
# 6        red triangle             None                    True
# 7            triangle     red triangle                   False
# 8     purple triangle             None                    True
# 9     purple triangle             None                    True
# 10       green circle             None                    True
# 11      purple circle             None                    True
# 12              green   green triangle                   False
# 13             circle       red circle                   False
# 14         red circle             None                    True
# 15    purple triangle             None                    True
# 16             square    purple square                   False
# 17                red       red square                   False
# 18         red square             None                    True
# 19             purple  purple triangle                   False
# 20         red square             None                    True
# 21         red circle             None                    True
# 22     green triangle             None                    True
# 23      purple square             None                    True
# 24      purple circle             None                    True
# 25     green triangle             None                    True
# 26             purple  purple triangle                   False
# 27       green square             None                    True
# 28     green triangle             None                    True
# 29     green triangle             None                    True
# ...               ...              ...                     ...
# 1971     green circle             None                    True
# 1972       red square             None                    True
# 1973    purple square             None                    True
# 1974       red circle             None                    True
# 1975   green triangle             None                    True
# 1976   green triangle             None                    True
# 1977    purple square             None                    True
# 1978           purple    purple circle                   False
# 1979           purple    purple square                   False
# 1980    purple circle             None                    True
# 1981           purple  purple triangle                   False
# 1982    purple square             None                    True
# 1983           square     green square                   False
# 1984         triangle     red triangle                   False
# 1985              red       red square                   False
# 1986           square       red square                   False
# 1987           circle       red circle                   False
# 1988    purple circle             None                    True
# 1989           square     green square                   False
# 1990    purple circle             None                    True
# 1991           circle    purple circle                   False
# 1992              red     red triangle                   False
# 1993    purple circle             None                    True
# 1994     green square             None                    True
# 1995    purple circle             None                    True
# 1996  purple triangle             None                    True
# 1997            green     green square                   False
# 1998     green square             None                    True
# 1999           purple    purple square                   False
# 2000           purple    purple circle                   False
#
#       RSA_S1R1_rAchievesGoal  RSA_S1R1_goalAchieved  RSA_S1R1_utility  \
# 0                      False                   True                 1
# 1                       True                   True                 4
# 2                      False                   True                 0
# 3                      False                   True                 1
# 4                      False                  False                -5
# 5                       True                   True                 2
# 6                      False                   True                 3
# 7                       True                   True                 5
# 8                      False                   True                 2
# 9                      False                   True                 1
# 10                     False                   True                 6
# 11                     False                   True                 1
# 12                      True                   True                 3
# 13                      True                   True                 2
# 14                     False                   True                -1
# 15                     False                   True                 2
# 16                      True                   True                 5
# 17                     False                  False                -4
# 18                     False                   True                 2
# 19                      True                   True                 4
# 20                     False                   True                 1
# 21                     False                   True                 4
# 22                     False                   True                -1
# 23                     False                   True                -1
# 24                     False                   True                 1
# 25                     False                   True                 3
# 26                      True                   True                 6
# 27                     False                   True                 7
# 28                     False                   True                 5
# 29                     False                   True                 1
# ...                      ...                    ...               ...
# 1971                   False                   True                 5
# 1972                   False                   True                 2
# 1973                   False                   True                 5
# 1974                   False                   True                -1
# 1975                   False                   True                 5
# 1976                   False                   True                 3
# 1977                   False                   True                 0
# 1978                    True                   True                 4
# 1979                    True                   True                 6
# 1980                   False                   True                 3
# 1981                    True                   True                 5
# 1982                   False                   True                -1
# 1983                    True                   True                 6
# 1984                    True                   True                 2
# 1985                    True                   True                 6
# 1986                    True                   True                 7
# 1987                   False                  False                -2
# 1988                   False                   True                 0
# 1989                    True                   True                 4
# 1990                   False                   True                 5
# 1991                   False                  False                -4
# 1992                   False                  False                -1
# 1993                   False                   True                 6
# 1994                   False                   True                 0
# 1995                   False                   True                 4
# 1996                   False                   True                 3
# 1997                   False                  False                -2
# 1998                   False                   True                 4
# 1999                    True                   True                 5
# 2000                    True                   True                 3
#
#      CentralControl_utility_R CentralControl_actor_R  DIYSignaler_utility
# 0                           6               receiver                    1
# 1                           4               receiver                   -3
# 2                           5               receiver                    0
# 3                           4               receiver                    1
# 4                           4               receiver                   -1
# 5                           2               receiver                    1
# 6                           3               signaler                    3
# 7                           5               receiver                    0
# 8                           5               receiver                    2
# 9                           4               receiver                    1
# 10                          6               signaler                    6
# 11                          6               receiver                    1
# 12                          3               receiver                    0
# 13                          2               receiver                    1
# 14                          6               receiver                   -1
# 15                          3               receiver                    2
# 16                          5               receiver                    4
# 17                          4               receiver                   -3
# 18                          3               receiver                    2
# 19                          4               receiver                   -3
# 20                          6               receiver                    1
# 21                          4               signaler                    4
# 22                          2               receiver                   -1
# 23                          2               receiver                   -1
# 24                          4               receiver                    1
# 25                          3               signaler                    3
# 26                          6               receiver                    3
# 27                          7               signaler                    7
# 28                          5               signaler                    5
# 29                          1               signaler                    1
# ...                       ...                    ...                  ...
# 1971                        5               signaler                    5
# 1972                        2               signaler                    2
# 1973                        5               signaler                    5
# 1974                        4               receiver                   -1
# 1975                        5               signaler                    5
# 1976                        4               receiver                    3
# 1977                        1               receiver                    0
# 1978                        4               receiver                   -3
# 1979                        6               receiver                    1
# 1980                        4               receiver                    3
# 1981                        5               receiver                   -2
# 1982                        2               receiver                   -1
# 1983                        6               receiver                    1
# 1984                        2               receiver                   -1
# 1985                        6               receiver                    3
# 1986                        7               receiver                    0
# 1987                        2               receiver                   -5
# 1988                        1               receiver                    0
# 1989                        4               receiver                    1
# 1990                        5               signaler                    5
# 1991                        3               receiver                   -4
# 1992                        3               receiver                   -2
# 1993                        6               signaler                    6
# 1994                        5               receiver                    0
# 1995                        4               signaler                    4
# 1996                        3               signaler                    3
# 1997                        5               receiver                   -2
# 1998                        4               signaler                    4
# 1999                        5               receiver                    0
# 2000                        3               receiver                    2
#
# [2001 rows x 64 columns]

# %%
def getPercentFromOptimalUtilityDF(df):
    percentFromOptimalUtil = pd.DataFrame(index=df.index)
    utilityColumns = [x for x in df.columns if 'utility' in x]
    
    for utilityName in utilityColumns:
        u_optimal = 'CentralControl_utility'
        percentFromOptimalUtil[utilityName] = 100.0*(df[utilityName]/df[u_optimal])#df[utilityName]-df[u_optimal] #
    return(percentFromOptimalUtil)

# %%
def getProportionTargetReached(df):
    propTrialsTargetReached = pd.DataFrame(columns=['signaler', 'receiver'])
    getPropTrue =  lambda colName: df[colName].value_counts(normalize=True).loc[True] if (True in df[colName].value_counts(normalize=True).index) else 0.0
    
    sLabels = [x for x in df.columns if 'sAchievesGoal' in x]
    rLabels = [x for x in df.columns if 'rAchievesGoal' in x]
    for s, r in zip(sLabels, rLabels):
        propTrialsTargetReached.loc[s] = [getPropTrue(s), getPropTrue(r)]

    propTrialsTargetReached['total'] = propTrialsTargetReached['signaler'] + propTrialsTargetReached['receiver']

    propTrialsTargetReached['marginOfErrorS'] =  1.96*np.sqrt((propTrialsTargetReached['signaler']*(1-propTrialsTargetReached['signaler']))/df.shape[0])
    propTrialsTargetReached['marginOfErrorR'] =  1.96*np.sqrt((propTrialsTargetReached['receiver']*(1-propTrialsTargetReached['receiver']))/df.shape[0])

    return(propTrialsTargetReached)

# %%
rsaAcc = getProportionTargetReached(df)

# %%
rsaAcc.loc[['IW_N_sAchievesGoal', 'IW_S1R0_sAchievesGoal', 'IW_P_sAchievesGoal', 'IW_S1R1_sAchievesGoal', 'RSA_PA_sAchievesGoal', 'RSA_S1R1_sAchievesGoal']]
# Out:
#                         signaler  receiver     total  marginOfErrorS  \
# IW_N_sAchievesGoal      0.464268  0.462269  0.926537        0.021852
# IW_S1R0_sAchievesGoal   0.462769  0.462269  0.925037        0.021847
# IW_P_sAchievesGoal      0.463768  0.505247  0.969015        0.021850
# IW_S1R1_sAchievesGoal   0.464768  0.498751  0.963518        0.021854
# RSA_PA_sAchievesGoal    0.576212  0.331334  0.907546        0.021652
# RSA_S1R1_sAchievesGoal  0.582709  0.330835  0.913543        0.021606
#
#                         marginOfErrorR
# IW_N_sAchievesGoal            0.021846
# IW_S1R0_sAchievesGoal         0.021846
# IW_P_sAchievesGoal            0.021907
# IW_S1R1_sAchievesGoal         0.021908
# RSA_PA_sAchievesGoal          0.020624
# RSA_S1R1_sAchievesGoal        0.020616

# %%
meanUtilDifferenceRSA = getPercentFromOptimalUtilityDF(df).mean()
meanUtilDifferenceRSA.loc[['IW_N_utility', 'IW_S1R0_utility', 'IW_P_utility', 'IW_S1R1_utility', 'RSA_PA_utility', 'RSA_S1R1_utility']]
# Out:
# IW_N_utility        82.630946
# IW_S1R0_utility     82.316699
# IW_P_utility        90.391233
# IW_S1R1_utility     89.451584
# RSA_PA_utility      67.668666
# RSA_S1R1_utility    67.874753
# dtype: float64
